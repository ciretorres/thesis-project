# %%
import pandas

# %%
# la que utiliza Prototype_v1
hip_100pc = "data_raw/hip_100pc.csv"
# la que utiliza el anexo de estrellas prominentes y AbsMagSimilarToSun
hip_cat_2 = "data_raw/hip_cat_2.csv"

# %% [markdown]
# # hip_main

# %%
# https://cdsarc.cds.unistra.fr/ftp/I/239/
# https://cdsarc.cds.unistra.fr/ftp/I/239/hip_main.dat
hip_main = "data_raw/hip_main.dat"

columns = ['recno', 'HIP', 'Proxy', 'RAhms', 'DEdms', 'Vmag', 'VarFlag', 'r_Vmag',
       'RAICRS', 'DEICRS', 'AstroRef', 'Plx', 'pmRA', 'pmDE', 'e_RAICRS',
       'e_DEICRS', 'e_Plx', 'e_pmRA', 'e_pmDE', 'DE:RA', 'Plx:RA', 'Plx:DE',
       'pmRA:RA', 'pmRA:DE', 'pmRA:Plx', 'pmDE:RA', 'pmDE:DE', 'pmDE:Plx',
       'pmDE:pmRA', 'F1', 'F2', 'BTmag', 'e_BTmag', 'VTmag', 'e_VTmag',
       'm_BTmag', 'B-V', 'e_B-V', 'r_B-V', 'V-I', 'e_V-I', 'r_V-I', 'CombMag',
       'Hpmag', 'e_Hpmag', 'Hpscat', 'o_Hpmag', 'm_Hpmag', 'Hpmax', 'HPmin',
       'Period', 'HvarType', 'moreVar', 'morePhoto', 'CCDM', 'n_CCDM', 'Nsys',
       'Ncomp', 'MultFlag', 'Source', 'Qual', 'm_HIP', 'theta', 'rho', 'e_rho',
       'dHp', 'e_dHp', 'Survey', 'Chart', 'Notes', 'HD', 'BD', 'CoD', 'CPD',
       '(V-I)red', 'SpType', 'r_SpType', 'HIPep', 'Erratum', '_RA.icrs',
       '_DE.icrs']

# leer .dat
hip_main = pandas.read_table(hip_main, delimiter='|', names=columns, index_col = 'HIP')
hip_main
# Out:
# /var/folders/dn/_5cs1ryn0gj52lsxggsjh_sh0000gn/T/ipykernel_65804/3553582747.py:19: DtypeWarning: Columns (5,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   hip_main = pandas.read_table(hip_main, delimiter='|', names=columns, index_col = 'HIP')
#        recno Proxy        RAhms        DEdms  Vmag VarFlag r_Vmag  \
# HIP
# 1          H        00 00 00.22  +01 05 20.4   9.1              H
# 2          H        00 00 00.91  -19 29 55.8  9.27              G
# 3          H        00 00 01.20  +38 51 33.4  6.61              G
# 4          H        00 00 02.01  -51 53 36.8  8.06              H
# 5          H        00 00 02.39  -40 35 28.4  8.55              H
# ...      ...   ...          ...          ...   ...     ...    ...
# 118318     H        23 59 51.30  +11 40 25.4  6.99       1      H
# 118319     H        23 59 53.74  -22 25 41.4  8.23              G
# 118320     H        23 59 54.25  +05 57 23.9  7.59              H
# 118321     H        23 59 54.78  -64 22 21.3   9.2              G
# 118322     H        23 59 54.91  -65 34 37.5  4.49              H
#
#               RAICRS        DEICRS AstroRef  ...      BD         CoD  \
# HIP                                          ...
# 1       000.00091185  +01.08901332           ...  224700  B+00 5077
# 2       000.00379737  -19.49883745        +  ...  224690  B-20 6688
# 3       000.00500795  +38.85928608           ...  224699  B+38 5108
# 4       000.00838170  -51.89354612           ...  224707
# 5       000.00996534  -40.59122440           ...  224705
# ...              ...           ...      ...  ...     ...         ...
# 118318  359.96374383  +11.67370866           ...  224673  B+10 5018
# 118319  359.97391252  -22.42818030           ...  224693
# 118320  359.97605747  +05.95663786           ...  224689  B+05 5245
# 118321  359.97823891  -64.37257220           ...  224685
# 118322  359.97879195  -65.57707774           ...  224686
#
#                CPD    (V-I)red SpType      r_SpType HIPep Erratum _RA.icrs  \
# HIP
# 1                                0.66  F5              S      NaN      NaN
# 2                                1.04  K3V             4      NaN      NaN
# 3                                0.00  B9              S      NaN      NaN
# 4                   P-52 12237   0.43  F0V             2      NaN      NaN
# 5       C-41 15372  P-41  9991   0.95  G8III           2      NaN      NaN
# ...            ...         ...    ...           ...   ...     ...      ...
# 118318                           1.56  K2              S      NaN      NaN
# 118319  C-23 18108  P-23  8366   0.70  G2V             4      NaN      NaN
# 118320                           0.98  K0              S      NaN      NaN
# 118321  C-65  2958  P-65  4188   0.75  G5V             1      NaN      NaN
# 118322              P-66  3819  -0.04  B9IV            X      NaN      NaN
#
#        _DE.icrs
# HIP
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# ...         ...
# 118318      NaN
# 118319      NaN
# 118320      NaN
# 118321      NaN
# 118322      NaN
#
# [118218 rows x 80 columns]
